# %% [markdown]
# # Kiva Crowd Funding Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid');

# %%
Data=pd.read_csv("E:\Training\kiva_loans.csv")

# %%
Data
# Out:
#              id  funded_amount  loan_amount               activity  \
# 0        653051          300.0        300.0    Fruits & Vegetables
# 1        653053          575.0        575.0               Rickshaw
# 2        653068          150.0        150.0         Transportation
# 3        653063          200.0        200.0             Embroidery
# 4        653084          400.0        400.0             Milk Sales
# 5       1080148          250.0        250.0               Services
# 6        653067          200.0        200.0                  Dairy
# 7        653078          400.0        400.0           Beauty Salon
# 8        653082          475.0        475.0          Manufacturing
# 9        653048          625.0        625.0  Food Production/Sales
# 10       653060          200.0        200.0               Rickshaw
# 11       653088          400.0        400.0              Wholesale
# 12       653089          400.0        400.0          General Store
# ...

# %%
Data.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
Data.tail()
# Out:
#              id  funded_amount  loan_amount   activity         sector  \
# 671200  1340323            0.0         25.0  Livestock    Agriculture
# 671201  1340316           25.0         25.0  Livestock    Agriculture
# 671202  1340334            0.0         25.0      Games  Entertainment
# 671203  1340338            0.0         25.0  Livestock    Agriculture
# 671204  1340339            0.0         25.0  Livestock    Agriculture
#
#                                                       use country_code  \
# 671200  [True, u'para compara: cemento, arenya y ladri...           PY
# 671201  [True, u'to start a turducken farm.'] - this l...           KE
# 671202                                                NaN           KE
# 671203  [True, u'to start a turducken farm.'] - this l...           KE
# 671204  [True, u'to start a turducken farm.'] - this l...           KE
#
#          country      region currency  partner_id                posted_time  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null object
# disbursed_time        668809 non-null object
# funded_time           622874 non-null object
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  499789 non-null object
# borrower_genders      666984 non-null object
# ...

# %%
Data.describe()
# Out:
#                  id  funded_amount    loan_amount     partner_id  \
# count  6.712050e+05  671205.000000  671205.000000  657698.000000
# mean   9.932486e+05     785.995061     842.397107     178.199616
# std    1.966113e+05    1130.398941    1198.660073      94.247581
# min    6.530470e+05       0.000000      25.000000       9.000000
# 25%    8.230720e+05     250.000000     275.000000     126.000000
# 50%    9.927800e+05     450.000000     500.000000     145.000000
# 75%    1.163653e+06     900.000000    1000.000000     204.000000
# max    1.340339e+06  100000.000000  100000.000000     536.000000
#
#        term_in_months   lender_count
# count   671205.000000  671205.000000
# mean        13.739022      20.590922
# std          8.598919      28.459551
# min          1.000000       0.000000
# 25%          8.000000       7.000000
# 50%         13.000000      13.000000
# 75%         14.000000      24.000000
# max        158.000000    2986.000000

# %%
Data.country.value_counts()
# Out:
# Philippines                         160441
# Kenya                                75825
# El Salvador                          39875
# Cambodia                             34836
# Pakistan                             26857
# Peru                                 22233
# Colombia                             21995
# Uganda                               20601
# Tajikistan                           19580
# Ecuador                              13521
# Paraguay                             11903
# Nicaragua                            11781
# India                                11237
# Vietnam                              10843
# Nigeria                              10136
# Bolivia                               8806
# Lebanon                               8792
# Armenia                               8631
# Palestine                             8167
# Samoa                                 7396
# Guatemala                             7310
# Rwanda                                6735
# ...

# %%
 # to find Frequency of loans in each sector

# %%
Data['sector'].value_counts().plot(kind="area",figsize=(12,12))        #figsize-to expand plot
plt.xticks(np.arange(15),(Data['sector'].unique()),rotation=60)        #rotaion - to rotate sector name 
plt.show()

# %%
# to check correlation by regression plot
    # here we see that the corr coeff is 0.84, it means there is highly correlation between lender count and funded_amount

# %%
print("Correlation coefficent of funded amount and lender count: ",Data['funded_amount'].corr(Data['lender_count']))
sns.jointplot(x="funded_amount", y="lender_count", data=Data, kind='reg')
sns.set_style('whitegrid');
# Out:
# ('Correlation coefficent of funded amount and lender count: ', 0.8491677331060971)

# %%
# to check correlation of funded amount and loan amount
     # here we see that the corr coeff is 0.94.it means othere ishigh correlation between funded amount and loan amount.
     # It means when the loan could not be fully funded, which explains why the correlation coefficient isn't exactly 1.

# %%
print(Data['funded_amount'].corr(Data['loan_amount']))
sns.jointplot(x="funded_amount", y="loan_amount", data=Data, kind='reg')
sns.set_style('whitegrid');
# Out:
# 0.9450439566745138

# %%
plt.figure(figsize=(10,8))
sector_name = kiva['sector'].value_counts().head(10)
sns.barplot(sector_name.values, sector_name.index)
for i, v in enumerate(sector_name.values):
    plt.text(0.1,i,v,color='k',fontsize=15)
plt.xlabel('Number of loans were given')
plt.ylabel('Sector Name')
plt.title("Top sectors in which more loans were given")
plt.show()

# %%
## to see repayment

# %%
plt.figure(figsize=(10,8))
count = Data['repayment_interval'].value_counts()
sns.barplot(count.values, count.index, )
for i, v in enumerate(count.values):
    plt.text(0.8,i,v,color='k',fontsize=15)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Types of repayment interval', fontsize=15)
plt.title("Types of repayment intervals with their count", fontsize=15)
# Out:
# Text(0.5,1,u'Types of repayment intervals with their count')

# %%
my_plot_pie("loans", charttitle = "Percentage of different types of loans", 
              chartsubtitle = "[Funded, Partially funded and unfunded]", legendtitle = "Loans")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fe41ebe135c2> in <module>()
# ----> 1 my_plot_pie("loans", charttitle = "Percentage of different types of loans",
#       2               chartsubtitle = "[Funded, Partially funded and unfunded]", legendtitle = "Loans")
#
# NameError: name 'my_plot_pie' is not defined
